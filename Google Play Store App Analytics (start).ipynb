# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
print(df_apps.shape)
print(df_apps.columns)
df_apps.sample(5)
# Out:
# (10841, 12)
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')
#                                               App            Category  Rating  \
# 9100                   Crackle - Free TV & Movies       ENTERTAINMENT    3.70
# 7050                  Solid Explorer File Manager        PRODUCTIVITY    4.60
# 3409  Account Class-12 Solutions (D K Goel) Vol-2              FAMILY    4.60
# 422                             EW MOTION THERAPY  HEALTH_AND_FITNESS     NaN
# 4339                MultiMessage for FB Messenger        PRODUCTIVITY    4.20
#
#       Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 9100   388089      9.35  10,000,000  Free     0           Teen
# 7050    67523      4.00   1,000,000  Free     0       Everyone
# 3409      124     23.00      10,000  Free     0       Everyone
# 422         0      7.10          10  Free     0       Everyone
# 4339      182      7.00      50,000  Free     0       Everyone
#
#                 Genres    Last_Updated         Android_Ver
# 9100     Entertainment  April 12, 2018  Varies with device
# 7050      Productivity   July 19, 2018          4.1 and up
# 3409         Education  April 17, 2018          3.0 and up
# 422   Health & Fitness    July 9, 2018          4.1 and up
# 4339      Productivity  April 28, 2018          4.2 and up

# %%
df_apps.describe()
# Out:
#         Rating       Reviews  Size_MBs
# count 9,367.00     10,841.00 10,841.00
# mean      4.19    444,111.93     19.77
# std       0.52  2,927,628.66     21.40
# min       1.00          0.00      0.01
# 25%       4.00         38.00      4.90
# 50%       4.30      2,094.00     11.00
# 75%       4.50     54,768.00     27.00
# max       5.00 78,158,306.00    100.00

# %%
df_apps.isna().any()
# Out:
# App               False
# Category          False
# Rating             True
# Reviews           False
# Size_MBs          False
# Installs          False
# Type               True
# Price             False
# Content_Rating    False
# Genres            False
# Last_Updated      False
# Android_Ver        True
# dtype: bool

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)
df_apps.sample(5)
# Out:
#                                                      App      Category  \
# 4120                            Neuvaine au Saint-Esprit     LIFESTYLE
# 7223   Sephora: Skin Care, Beauty Makeup & Fragrance ...        BEAUTY
# 6560   Free Messages, Video, Chat,Text for Messenger ...        SOCIAL
# 10270                                         Love Balls          GAME
# 4443                                          To-do list  PRODUCTIVITY
#
#        Rating  Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 4120     4.70       57      5.80      10,000  Free     0       Everyone
# 7223     4.50    26834     57.00   1,000,000  Free     0       Everyone
# 6560     4.30     6086      3.10   1,000,000  Free     0           Teen
# 10270    4.20   360630     40.00  50,000,000  Free     0       Everyone
# 4443     4.40      688      4.40      50,000  Free     0       Everyone
#
#              Genres
# 4120      Lifestyle
# 7223         Beauty
# 6560         Social
# 10270        Puzzle
# 4443   Productivity

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
duplicated_rows.head(10)
# Out:
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
# 1379             CT Scan Cross Sectional Anatomy  MEDICAL    4.30       10
# 1616                   JH Blood Pressure Monitor  MEDICAL    3.70        9
# 1642      Cardi B Live Stream Video Chat - Prank   DATING    4.40       28
# 1813                     Diabetes & Diet Tracker  MEDICAL    4.60      395
# 1821    Transenger – Ts Dating and Chat for Free   DATING    3.60        8
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating
# 1379     46.00      100  Free       0       Everyone  Medical
# 1616      2.90      500  Free       0       Everyone  Medical
# 1642      3.40      500  Free       0       Everyone   Dating
# 1813     19.00    1,000  Paid   $9.99       Everyone  Medical
# 1821     14.00    1,000  Free       0     Mature 17+   Dating

# %%
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean = df_apps_clean.drop_duplicates()
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])

# %%
print(df_apps_clean.shape)
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
# (8199, 10)
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean[df_apps_clean.Rating == df_apps_clean.Rating.max()].head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21     25.00        1  Free      0       Everyone  Medical
# 28     20.00        1  Paid  $1.49       Everyone   Arcade
# 47     16.00        1  Paid  $0.99       Everyone   Arcade
# 82     19.00        5  Free      0       Everyone   Arcade
# 99      4.60        5  Free      0       Everyone  Medical

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean[df_apps_clean.Size_MBs == df_apps_clean.Size_MBs.max()].head()
# Out:
#                                                    App            Category  \
# 1795                              Navi Radiography Pro             MEDICAL
# 3144                                        Vi Trainer  HEALTH_AND_FITNESS
# 4176  Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 7926                                         Post Bank             FINANCE
# 7927                       The Walking Dead: Our World                GAME
#
#       Rating  Reviews  Size_MBs   Installs  Type   Price Content_Rating  \
# 1795    4.70       11    100.00        500  Paid  $15.99       Everyone
# 3144    3.60      124    100.00      5,000  Free       0       Everyone
# 4176    3.60      151    100.00     10,000  Free       0       Everyone
# 7926    4.50    60449    100.00  1,000,000  Free       0       Everyone
# 7927    4.00    22435    100.00  1,000,000  Free       0           Teen
#
#                 Genres
# 1795           Medical
# 3144  Health & Fitness
# 4176            Racing
# 7926           Finance
# 7927            Action

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head(5)
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# 10650       Strategy

# %%
top_reviews = df_apps_clean.sort_values('Reviews', ascending=False).head(50)
print(f'Number of paid apps in the Top 50 reviewed: {top_reviews[top_reviews.Price != "0"].App.count()}')
# Out:
# Number of paid apps in the Top 50 reviewed: 0

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
category_count = df_apps_clean.groupby('Category').App.count()
print(category_count.values)
print(type(category_count.values[0]))
category_count.index
# Out:
# [  61   73   42  169  262   54  257  134  118  102   45 1610  302   94
#   910  243   62   64  302  118  292  204   50  298  263  301  180  203
#   260  719  187  148   72]
# <class 'numpy.int64'>
# Index(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY', 'BOOKS_AND_REFERENCE',
#        'BUSINESS', 'COMICS', 'COMMUNICATION', 'DATING', 'EDUCATION',
#        'ENTERTAINMENT', 'EVENTS', 'FAMILY', 'FINANCE', 'FOOD_AND_DRINK',
#        'GAME', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME', 'LIBRARIES_AND_DEMO',
#        'LIFESTYLE', 'MAPS_AND_NAVIGATION', 'MEDICAL', 'NEWS_AND_MAGAZINES',
#        'PARENTING', 'PERSONALIZATION', 'PHOTOGRAPHY', 'PRODUCTIVITY',
#        'SHOPPING', 'SOCIAL', 'SPORTS', 'TOOLS', 'TRAVEL_AND_LOCAL',
#        'VIDEO_PLAYERS', 'WEATHER'],
#       dtype='object', name='Category')

# %%
# pie chart

fig = px.pie(values=category_count.values, names=category_count.index, title='Categories of download')

fig.show()

# %%
# donut chart -- add hole=

fig = px.pie(values=category_count.values, names=category_count.index, hole=0.5, title='Categories of download')

fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
# make sure price and install columns are string type

df_apps_clean[df_apps_clean.Price != "0"].sample(5)
# Out:
#                             App             Category  Rating  Reviews  \
# 4230               Power Widget                TOOLS    4.20      928
# 1291     Hey AJ! It's Saturday!  BOOKS_AND_REFERENCE    5.00       12
# 2689                   OptoDrum              MEDICAL    3.90       10
# 6364  Assassin's Creed Identity                 GAME    3.70    42529
# 2651                 iHunter BC               SPORTS    4.40       55
#
#       Size_MBs Installs  Type  Price Content_Rating             Genres
# 4230      0.37   10,000  Paid  $1.99       Everyone              Tools
# 1291     50.00      100  Paid  $3.99       Everyone  Books & Reference
# 2689      0.37    1,000  Paid  $5.99       Everyone            Medical
# 6364     92.00  500,000  Paid  $1.99           Teen             Action
# 2651     63.00    1,000  Paid  $4.49       Everyone             Sports

# %%
# remove commas and dollar signs to convert into float succesfully (remove nun-numeric characters)
#  
df_apps_clean.Price = df_apps_clean.Price.str.replace("$", "")
df_apps_clean.Installs = df_apps_clean.Installs.str.replace(",", "")
df_apps_clean[df_apps_clean.Price != "0"].sample(5)
# Out:
# C:\Users\OWNER\AppData\Local\Temp\ipykernel_1772\4026344576.py:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                                App             Category  Rating  Reviews  \
# 2171  Next Launcher 3D Theme Hit-B      PERSONALIZATION    4.40       83
# 5477                  DRAGON QUEST               FAMILY    4.20     9659
# 3413               BringGo AU & NZ  MAPS_AND_NAVIGATION    2.80      440
# 2649           Sago Mini Hat Maker            EDUCATION    4.90       11
# 3856                 I am rich VIP            LIFESTYLE    3.80      411
#
#       Size_MBs Installs  Type   Price Content_Rating                  Genres
# 2171      8.60     1000  Paid    1.70       Everyone         Personalization
# 5477     30.00   100000  Paid    2.99       Everyone            Role Playing
# 3413     23.00    10000  Paid    0.99       Everyone       Maps & Navigation
# 2649     63.00     1000  Paid    3.99       Everyone  Education;Pretend Play
# 3856      2.60    10000  Paid  299.99       Everyone               Lifestyle

# %%
# convert the data types and make sure they are ok
df_apps_clean.Price = df_apps_clean.Price.astype(float)
df_apps_clean.Installs = df_apps_clean.Installs.astype(float)
df_apps_clean[df_apps_clean.Price > 0].sample(5)
# Out:
#                                                  App        Category  Rating  \
# 2159  X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN    4.70
# 2505                                WIZARD Card Game            GAME    4.00
# 1899                               Avokiddo Emotions          FAMILY    4.60
# 2768                   Basketball Dynasty Manager 16          SPORTS    4.40
# 540                       meStudying: AP English Lit          FAMILY    5.00
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 2159      149      3.50  1,000.00  Paid   1.99       Everyone
# 2505       48      4.10  1,000.00  Paid   1.99       Everyone
# 1899       73     12.00  1,000.00  Paid   2.99       Everyone
# 2768      426     21.00  5,000.00  Paid   1.99       Everyone
# 540         1      0.64     10.00  Paid   4.99       Everyone
#
#                       Genres
# 2159            Art & Design
# 2505                    Card
# 1899  Education;Pretend Play
# 2768                  Sports
# 540                Education

# %%
# count billion and single downloaded apps

print(f"Number of apps that had over a billion download: {df_apps_clean[df_apps_clean.Installs >= 1000000000].Installs.count()}")
print(f"Number of apps that had a single download: {df_apps_clean[df_apps_clean.Installs == 1].Installs.count()}")
df_apps_clean[df_apps_clean.Installs >= 1000000000]
# Out:
# Number of apps that had over a billion download: 20
# Number of apps that had a single download: 3
#                                             App             Category  Rating  \
# 10783                         Google Play Books  BOOKS_AND_REFERENCE    3.90
# 10784  Messenger – Text and Video Chat for Free        COMMUNICATION    4.00
# 10785                        WhatsApp Messenger        COMMUNICATION    4.40
# 10786              Google Chrome: Fast & Secure        COMMUNICATION    4.30
# 10787                                     Gmail        COMMUNICATION    4.30
# 10788                                  Hangouts        COMMUNICATION    4.00
# 10792             Skype - free IM & video calls        COMMUNICATION    4.10
# 10803                         Google Play Games        ENTERTAINMENT    4.30
# 10805                                  Facebook               SOCIAL    4.10
# 10806                                 Instagram               SOCIAL    4.50
# 10807                                   Google+               SOCIAL    4.20
# 10813                             Google Photos          PHOTOGRAPHY    4.50
# 10817                 Maps - Navigate & Explore     TRAVEL_AND_LOCAL    4.30
# 10818                        Google Street View     TRAVEL_AND_LOCAL    4.20
# 10822                                    Google                TOOLS    4.40
# 10824                              Google Drive         PRODUCTIVITY    4.40
# 10828                                   YouTube        VIDEO_PLAYERS    4.30
# 10829                   Google Play Movies & TV        VIDEO_PLAYERS    3.70
# 10831                               Google News   NEWS_AND_MAGAZINES    3.90
# 10835                            Subway Surfers                 GAME    4.50
#
#         Reviews  Size_MBs         Installs  Type  Price Content_Rating  \
# 10783   1433233      5.70 1,000,000,000.00  Free   0.00           Teen
# 10784  56642847      3.50 1,000,000,000.00  Free   0.00       Everyone
# 10785  69119316      3.50 1,000,000,000.00  Free   0.00       Everyone
# 10786   9642995      3.50 1,000,000,000.00  Free   0.00       Everyone
# 10787   4604324      3.50 1,000,000,000.00  Free   0.00       Everyone
# 10788   3419249      3.50 1,000,000,000.00  Free   0.00       Everyone
# 10792  10484169      3.50 1,000,000,000.00  Free   0.00       Everyone
# 10803   7165362      9.35 1,000,000,000.00  Free   0.00           Teen
# 10805  78158306      5.30 1,000,000,000.00  Free   0.00           Teen
# 10806  66577313      5.30 1,000,000,000.00  Free   0.00           Teen
# 10807   4831125      5.30 1,000,000,000.00  Free   0.00           Teen
# 10813  10858556      6.90 1,000,000,000.00  Free   0.00       Everyone
# 10817   9235155     12.00 1,000,000,000.00  Free   0.00       Everyone
# 10818   2129689     12.00 1,000,000,000.00  Free   0.00       Everyone
# 10822   8033493      3.40 1,000,000,000.00  Free   0.00       Everyone
# 10824   2731171      4.00 1,000,000,000.00  Free   0.00       Everyone
# 10828  25655305      4.65 1,000,000,000.00  Free   0.00           Teen
# 10829    906384      4.65 1,000,000,000.00  Free   0.00           Teen
# 10831    877635     13.00 1,000,000,000.00  Free   0.00           Teen
# 10835  27722264     76.00 1,000,000,000.00  Free   0.00   Everyone 10+
#
#                         Genres
# 10783        Books & Reference
# 10784            Communication
# 10785            Communication
# 10786            Communication
# 10787            Communication
# 10788            Communication
# 10792            Communication
# 10803            Entertainment
# 10805                   Social
# 10806                   Social
# 10807                   Social
# 10813              Photography
# 10817           Travel & Local
# 10818           Travel & Local
# 10822                    Tools
# 10824             Productivity
# 10828  Video Players & Editors
# 10829  Video Players & Editors
# 10831         News & Magazines
# 10835                   Arcade

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
# find top 20 most expensive apps
df_apps_clean.sort_values('Price', ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 3897                       I Am Rich     FAMILY    3.60      217      4.90
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# 2281       Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407                    LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629                I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481         A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 4264         Golfshot Plus: Golf GPS     SPORTS    4.10     3387     25.00
#
#        Installs  Type  Price Content_Rating         Genres
# 3946  10,000.00  Paid 400.00       Everyone      Lifestyle
# 2461   1,000.00  Paid 399.99       Everyone        Finance
# 4606  50,000.00  Paid 399.99       Everyone        Finance
# 3145   5,000.00  Paid 399.99       Everyone        Finance
# 3554  10,000.00  Paid 399.99       Everyone      Lifestyle
# 5765 100,000.00  Paid 399.99       Everyone      Lifestyle
# 1946   1,000.00  Paid 399.99           Teen        Finance
# 2775   5,000.00  Paid 399.99       Everyone  Entertainment
# 3221  10,000.00  Paid 399.99       Everyone  Entertainment
# 3114   5,000.00  Paid 399.99       Everyone        Finance
# 1331     100.00  Paid 399.99       Everyone  Entertainment
# 2394   1,000.00  Paid 399.99       Everyone        Finance
# 3897  10,000.00  Paid 389.99       Everyone  Entertainment
# 2193   1,000.00  Paid 379.99       Everyone      Lifestyle
# 3856  10,000.00  Paid 299.99       Everyone      Lifestyle
# 2281   1,000.00  Paid  79.99       Everyone        Medical
# 1407     100.00  Paid  39.99       Everyone        Medical
# 2629   1,000.00  Paid  37.99       Everyone      Lifestyle
# 2481   1,000.00  Paid  33.99       Everyone        Medical
# 4264  50,000.00  Paid  29.99       Everyone         Sports

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# remove apps cost more than $250, then finding top 20 most expensive apps again

df_apps_clean = df_apps_clean[df_apps_clean.Price < 250]
df_apps_clean.sort_values('Price', ascending=False).head(20)
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL    4.60
# 1407                                       LTC AS Legal      MEDICAL    4.00
# 2629                                   I am Rich Person    LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture      MEDICAL    3.50
# 2463                                 PTA Content Master      MEDICAL    4.20
# 2207                                           EMT PASS      MEDICAL    3.40
# 4264                            Golfshot Plus: Golf GPS       SPORTS    4.10
# 504                           AP Art History Flashcards       FAMILY    5.00
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL    4.20
# 2119                                         NewTek NDI  PHOTOGRAPHY    3.50
# 4470                                  DRAGON QUEST VIII       FAMILY    4.50
# 2293                               Hospitalist Handbook      MEDICAL    4.80
# 526                          USMLE Step 2 CK Flashcards       FAMILY    5.00
# 2473                            boattheory.ch Full 2018       FAMILY    4.70
# 4090                             I am Rich Premium Plus      FINANCE    4.60
# 1508                                 SkyTest BU/GU Lite     BUSINESS    2.90
# 3778                            The World Ends With You         GAME    4.60
# 2603                         2017 EMRA Antibiotic Guide      MEDICAL    4.40
# 3439                            Trine 2: Complete Story         GAME    3.80
#
#       Reviews  Size_MBs   Installs  Type  Price Content_Rating        Genres
# 2281       92     32.00   1,000.00  Paid  79.99       Everyone       Medical
# 1407        6      1.30     100.00  Paid  39.99       Everyone       Medical
# 2629      134      1.80   1,000.00  Paid  37.99       Everyone     Lifestyle
# 2481      214     68.00   1,000.00  Paid  33.99       Everyone       Medical
# 2463       64     41.00   1,000.00  Paid  29.99       Everyone       Medical
# 2207       51      2.40   1,000.00  Paid  29.99       Everyone       Medical
# 4264     3387     25.00  50,000.00  Paid  29.99       Everyone        Sports
# 504         1     96.00      10.00  Paid  29.99     Mature 17+     Education
# 4772     2921     25.00 100,000.00  Paid  24.99       Everyone       Medical
# 3241      168     25.00  10,000.00  Paid  24.99       Everyone       Medical
# 2119       77      1.20   1,000.00  Paid  19.99       Everyone   Photography
# 4470     7812     27.00  50,000.00  Paid  19.99   Everyone 10+  Role Playing
# 2293       12     18.00   1,000.00  Paid  19.99       Everyone       Medical
# 526         1     40.00      10.00  Paid  19.99       Everyone     Education
# 2473       54     50.00   1,000.00  Paid  19.40       Everyone     Education
# 4090      459      2.00  10,000.00  Paid  18.99       Everyone       Finance
# 1508       28     20.00     500.00  Paid  17.99       Everyone      Business
# 3778     4108     13.00  10,000.00  Paid  17.99   Everyone 10+        Arcade
# 2603       12      3.80   1,000.00  Paid  16.99       Everyone       Medical
# 3439      252     11.00  10,000.00  Paid  16.99           Teen        Action

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean['Est_Revenue'] = df_apps_clean.Price * df_apps_clean.Installs
df_apps_clean.head()
# Out:
# C:\Users\OWNER\AppData\Local\Temp\ipykernel_1772\3526874089.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres  Est_Revenue
# 21     25.00      1.00  Free   0.00       Everyone  Medical         0.00
# 28     20.00      1.00  Paid   1.49       Everyone   Arcade         1.49
# 47     16.00      1.00  Paid   0.99       Everyone   Arcade         0.99
# 82     19.00      5.00  Free   0.00       Everyone   Arcade         0.00
# 99      4.60      5.00  Free   0.00       Everyone  Medical         0.00

# %%
df_apps_clean.sort_values('Est_Revenue', ascending=False).head(20)
# Out:
#                                                    App         Category  \
# 9220                                         Minecraft           FAMILY
# 8825                                     Hitman Sniper             GAME
# 7151                     Grand Theft Auto: San Andreas             GAME
# 7477                               Facetune - For Free      PHOTOGRAPHY
# 7977                           Sleep as Android Unlock        LIFESTYLE
# 6594                               DraStic DS Emulator             GAME
# 6082                                      Weather Live          WEATHER
# 7954                                       Bloons TD 5           FAMILY
# 7633                           Five Nights at Freddy's             GAME
# 6746                        Card Wars - Adventure Time           FAMILY
# 6856                                           Threema    COMMUNICATION
# 7044                                            Tasker            TOOLS
# 4772  Human Anatomy Atlas 2018: Complete 3D Human Body          MEDICAL
# 6406                             NBA JAM by EA SPORTS™           FAMILY
# 6496                             Beautiful Widgets Pro  PERSONALIZATION
# 6023                                   Toca Life: City        EDUCATION
# 7563                                        True Skate           SPORTS
# 7988                                 Where's My Water?           FAMILY
# 4264                           Golfshot Plus: Golf GPS           SPORTS
# 4912                                   DRAGON QUEST VI           FAMILY
#
#       Rating  Reviews  Size_MBs      Installs  Type  Price Content_Rating  \
# 9220    4.50  2376564     19.00 10,000,000.00  Paid   6.99   Everyone 10+
# 8825    4.60   408292     29.00 10,000,000.00  Paid   0.99     Mature 17+
# 7151    4.40   348962     26.00  1,000,000.00  Paid   6.99     Mature 17+
# 7477    4.40    49553     48.00  1,000,000.00  Paid   5.99       Everyone
# 7977    4.50    23966      0.85  1,000,000.00  Paid   5.99       Everyone
# 6594    4.60    87766     12.00  1,000,000.00  Paid   4.99       Everyone
# 6082    4.50    76593      4.75    500,000.00  Paid   5.99       Everyone
# 7954    4.60   190086     94.00  1,000,000.00  Paid   2.99       Everyone
# 7633    4.60   100805     50.00  1,000,000.00  Paid   2.99           Teen
# 6746    4.30   129603     23.00  1,000,000.00  Paid   2.99   Everyone 10+
# 6856    4.50    51110      3.50  1,000,000.00  Paid   2.99       Everyone
# 7044    4.60    43045      3.40  1,000,000.00  Paid   2.99       Everyone
# 4772    4.50     2921     25.00    100,000.00  Paid  24.99       Everyone
# 6406    4.30    56444     43.00    500,000.00  Paid   4.99       Everyone
# 6496    4.20    97890     14.00  1,000,000.00  Paid   2.49       Everyone
# 6023    4.70    31085     24.00    500,000.00  Paid   3.99       Everyone
# 7563    4.40   129409     73.00  1,000,000.00  Paid   1.99       Everyone
# 7988    4.70   188740     69.00  1,000,000.00  Paid   1.99       Everyone
# 4264    4.10     3387     25.00     50,000.00  Paid  29.99       Everyone
# 4912    4.40     3358     17.00    100,000.00  Paid  14.99       Everyone
#
#                          Genres   Est_Revenue
# 9220  Arcade;Action & Adventure 69,900,000.00
# 8825                     Action  9,900,000.00
# 7151                     Action  6,990,000.00
# 7477                Photography  5,990,000.00
# 7977                  Lifestyle  5,990,000.00
# 6594                     Action  4,990,000.00
# 6082                    Weather  2,995,000.00
# 7954                   Strategy  2,990,000.00
# 7633                     Action  2,990,000.00
# 6746    Card;Action & Adventure  2,990,000.00
# 6856              Communication  2,990,000.00
# 7044                      Tools  2,990,000.00
# 4772                    Medical  2,499,000.00
# 6406  Sports;Action & Adventure  2,495,000.00
# 6496            Personalization  2,490,000.00
# 6023     Education;Pretend Play  1,995,000.00
# 7563                     Sports  1,990,000.00
# 7988         Puzzle;Brain Games  1,990,000.00
# 4264                     Sports  1,499,500.00
# 4912               Role Playing  1,499,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
